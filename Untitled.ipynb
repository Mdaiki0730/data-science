# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 6, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
run -i matplot.py

# %%
run -i andBias.py
# Out:
# AND
# 0
# 0
# 0
# 1
# NAND
# 1
# 1
# 1
# 0
# OR
# 0
# 1
# 1
# 1
# XOR
# 0
# 1
# 1
# 0

# %%
run -i
